# %% [markdown]
# ![](https://i.imgur.com/3twMqGw.png)
#
# # 作業2 : 股票預測
#
# ## **請挑選一家公司來做預測**
#
# 資料集: [鉅亨網](https://www.cnyes.com/)
#
# > **資料集說明**
#
# 別人恐懼我貪婪，一張不賣奇蹟來。
#
# >**作業說明**
#
# **第一步驟**: 左上角 檔案->在雲端硬碟建立副本。
#
# **第二步驟**: 右上角 共用->取得連結->任何知道這個連結的人都能編輯
#
# **第三步驟**: 左上角 執行階段->更變執行類型->GPU。 可以加快模型速度
#
# **第四步驟**: 檔案名稱，請填寫你的學號，把副本上下引號刪掉
#
# 請 **隨意修改** 這個colab的程式來完成訓練RNN模型。**不必一定要照著todo提示走。**
# 繳交時記得改檔案標題的學號。
#
# 這次作業的重點在於RNN的維度問題。
#
# > **作業限制**
#
# 1. 不要動資料集、不要在訓練時偷看test data
# 2. 模型請手刻、手疊，**不要用Transfer Learning**，你可以手刻transformer。
# 3. **不要抄襲**
#
# > **作業繳交**
#
# 1. 完成訓練後保存output結果，更改**檔名學號**，左上角 檔案->下載 成ipynb檔。
# 2. 交一個**pdf**檔，裡面需要附上**你的作業colab連結(設為可編輯、所有人觀看)**、姓名學號年級、過程和執行結果的截圖，並說明你程式撰寫的過程、本次作業心得(字數不限)。
# 3. 上述三個檔案繳交至ee-class。(Text Generation、Stock、PDF)
#
# > **繳交期限**
#
# 1. 電子商務技術(IM5002): 期限至2021/5/16(一) 23:59分
# 2. 人工智慧與機器學習(IM3078): 期限至2022/5/16(一) 23:59分
# 3. 電子商務智慧技術(IMA0200): 期限至2022/5/14(六) 23:59分
#
# > **算分標準**
#
# Text Generation(20) + Stock RNN(30) + Predict function(20分) + 30分文件
# 1.  [Text Generation](https://colab.research.google.com/drive/1bMkAUaiivMaOr8Sd1Ui-KJeoFImEVUqA?usp=sharing) 換個其他資料集來訓練，完成就20分
# 2. Stock RNN完成模型就30分
# 3. predit function有寫出來就20分(第七段)
# 4. 30分是文件分數
# 5. 記得把以上評分標準截圖、並與你的心得一起貼上pdf
#
# 有問題再來信助教: chiachentu@g.ncu.edu.tw(凃家甄)、lufor129@g.ncu.edu.tw(黃智輝)

# %%
# 太多人同時存取可能會報cannot retrieve file error
# 點擊you may still be able to access 下面那個連結再自行上傳檔案即可

import os

if(os.path.isfile("./train.csv") == False or os.path.isfile("./test.csv") == False):
  # !wget -O train.csv "http://140.115.82.54/NN/Recurrent/train.csv"
  # !wget -O test.csv "http://140.115.82.54/NN/Recurrent/test.csv"
  # !gdown --id 1iK40K9oXsmhJGs7XSn7q3I1XuPtsZiSj --output "./train.csv"
  # !gdown --id 1kZIgeeTnzQf6GJGJuqOe9BgkFa8qb7hJ --output "./test.csv"
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1iK40K9oXsmhJGs7XSn7q3I1XuPtsZiSj
# To: /content/train.csv
# 100% 138k/138k [00:00<00:00, 73.1MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1kZIgeeTnzQf6GJGJuqOe9BgkFa8qb7hJ
# To: /content/test.csv
# 100% 2.36k/2.36k [00:00<00:00, 2.83MB/s]

# %% [markdown]
# ## 1. 讀入Package

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import random
import datetime
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 2. 取得資料集

# %%
train_df = pd.read_csv("./train.csv")
train_df = train_df[::-1]
print("company : ",train_df["company"].unique())
train_df.head()
# Out:
# company :  [2317 2454 2330]
#       company      date  price
# 6687     2317  2012/1/2   81.4
# 6686     2317  2012/1/3   82.7
# 6685     2317  2012/1/4   83.2
# 6684     2317  2012/1/5   83.2
# 6683     2317  2012/1/6   83.9

# %%
test_df = pd.read_csv("./test.csv")
test_df = test_df[::-1]
print("test data shape : ",test_df.shape)
test_df.head()
# Out:
# test data shape :  (117, 3)
#      company      date  price
# 116     2317  2021/2/1  113.0
# 115     2317  2021/2/2  116.5
# 114     2317  2021/2/3  116.5
# 113     2317  2021/2/4  114.0
# 112     2317  2021/2/5  113.5

# %%
####################################
#                 #
# 自己決定三家公司哪家公司(填數字)#
# 挑選一家公司來做訓練、預測   #
#                 #
#                 #
####################################
companys = {"2330":"TSMC","2454":"MEDIATEK","2317":"FOXCONN"}
company_id = 2317

# %%
company = train_df[train_df["company"] == company_id]
company.index = company["date"]
company.head()
# Out:
#           company      date  price
# date
# 2012/1/2     2317  2012/1/2   81.4
# 2012/1/3     2317  2012/1/3   82.7
# 2012/1/4     2317  2012/1/4   83.2
# 2012/1/5     2317  2012/1/5   83.2
# 2012/1/6     2317  2012/1/6   83.9

# %%
def include_last_iter(start,end,step):
  i = start
  while i < end:
      yield i
      i += step
  yield end-1

# %%
plt.figure(figsize=(16, 8))
plt.subplots_adjust(hspace=0.5)
for index,c in enumerate(companys):
  plt.subplot(2,2,index+1)
  company_df = train_df[train_df["company"] == int(c)]
  plt.plot(company_df["date"],company_df["price"])
  plt.xticks(list(include_last_iter(0,company_df.shape[0],250)),rotation=30)
  plt.title(companys[c])
  plt.xlabel("Date")
  plt.ylabel("price")
    
plt.show()

# %% [markdown]
# ## 3. 資料前處理

# %%
# 切分training data & validation data
total_len = company.shape[0]
training_len = 2100
validation_data = total_len - training_len

print("總共有 : ",total_len,"筆")
print("訓練用 : (前)",training_len,"筆")
print("驗證用 : (後)",validation_data,"筆")
# Out:
# 總共有 :  2225 筆
# 訓練用 : (前) 2100 筆
# 驗證用 : (後) 125 筆

# %%
# 自己做 MinMax Transformer 前處理 
class MinMaxTransformer:
  def __init__(self):
    self.min = None
    self.max = None
    self.distance = None

  def fit(self,data):
    self.min = min(data)
    self.max = max(data)
    self.distance = self.max - self.min
    out = [(d-self.min)/self.distance for d in data]
    return out

  def recover(self,data):
    out = [d*self.distance+self.min for d in data]
    return out

  def transform(self,data):
    out = [(d-self.min)/self.distance for d in data]
    return out

  def transform_one(self,data):
    return (data-self.min)/self.distance

# %%
train_prices = company["price"].values

scalar = MinMaxTransformer()
scalar_data = scalar.fit(train_prices)

# %%
# 做正規化
print("origin data : ",train_prices[:5])
print("transform data : ",scalar_data[:5])
print("recover data : ",scalar.recover(scalar_data[:5]))
# Out:
# origin data :  [81.4 82.7 83.2 83.2 83.9]
# transform data :  [0.2663139329805998, 0.289241622574956, 0.2980599647266315, 0.2980599647266315, 0.3104056437389772]
# recover data :  [81.4, 82.7, 83.2, 83.2, 83.9]

# %%
# 切分資料集
training_data = scalar_data[:training_len]
validation_data = scalar_data[training_len:]

# %%
# todo 決定Seq長度
seq_len = 10

def split_input_target(seq):
  input_txt = tf.expand_dims(seq[:-1],-1)
  target_txt = tf.expand_dims(seq[1:],-1)
  return input_txt,target_txt

# %%
def make_ds(data):
  data_slice = tf.data.Dataset.from_tensor_slices(data)
  data_sequence = data_slice.batch(seq_len+1,drop_remainder=True)

  dataset = data_sequence.map(split_input_target)
  return dataset

# %%
# 製作資料集
train_ds = make_ds(training_data)
val_ds = make_ds(validation_data)

for input_example,target_exaple in train_ds.take(1):
  print("Input :", scalar.recover(input_example.numpy()))
  print("Target:", scalar.recover(target_exaple.numpy()))
  print("-"*50)
  print("Input :", input_example.numpy())
  print("Target:", target_exaple.numpy())
# Out:
# Input : [array([81.4]), array([82.7]), array([83.2]), array([83.2]), array([83.9]), array([84.3]), array([86.4]), array([86.2]), array([86.6]), array([85.2])]
# Target: [array([82.7]), array([83.2]), array([83.2]), array([83.9]), array([84.3]), array([86.4]), array([86.2]), array([86.6]), array([85.2]), array([83.5])]
# --------------------------------------------------
# Input : [[0.26631393]
#  [0.28924162]
#  [0.29805996]
#  [0.29805996]
#  [0.31040564]
#  [0.31746032]
#  [0.35449735]
#  [0.35097002]
#  [0.35802469]
#  [0.33333333]]
# Target: [[0.28924162]
#  [0.29805996]
#  [0.29805996]
#  [0.31040564]
#  [0.31746032]
#  [0.35449735]
#  [0.35097002]
#  [0.35802469]
#  [0.33333333]
#  [0.30335097]]

# %%
# Batch size
# todo 決定Batch大小
BATCH_SIZE = 25

BUFFER_SIZE = training_len

train_ds = train_ds.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_ds = val_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## 4. 建立模型
#
# 提示: Output是一個數值，所以Model output維度為1。
#
# * 輸入維度應為: (batch,seq_len,1)
#
# * 輸出維度應為: (batch,seq_len,1)
#
# **最後一層Dense不要加上任何activation function。**

# %%
# todo
input_shape = (seq_len, 1)
output_shape = [BATCH_SIZE, seq_len ,1 ]

keras.backend.clear_session()
model = tf.keras.Sequential(
    [
      layers.LSTM(units = 4096,input_shape=input_shape,return_sequences=True),
      layers.LSTM(units = 2048,input_shape=input_shape,return_sequences=True),
      layers.LSTM(units = 1024,input_shape=input_shape,return_sequences=True),
      layers.Dropout(0.3),
      layers.Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 4096)          67141632
#
#  lstm_1 (LSTM)               (None, 10, 2048)          50339840
#
#  lstm_2 (LSTM)               (None, 10, 1024)          12587008
#
#  dropout (Dropout)           (None, 10, 1024)          0
#
#  dense (Dense)               (None, 10, 1)             1025
#
# =================================================================
# Total params: 130,069,505
# Trainable params: 130,069,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. 制定訓練計畫並訓練
#
# 我們做數字相關預測，可以考慮用Mean_Squared_Error
#
# 公式:
# $$MSE = \frac{1}{n} \sum_{i=1}^N({\gamma-\hat{\gamma}})^2$$
#
#
# 提示:
# 不用管公式在幹嘛，compile帶入mean_squared_error。

# %%
# todo
epochs = 200

# todo
# model.compile
model.compile(loss='mean_squared_error', optimizer='adam')

# todo
# model.fit
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    epochs = epochs,
    validation_data=val_ds,
    shuffle=True
)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 12s 500ms/step - loss: 0.0231 - val_loss: 0.0237
# Epoch 2/200
# 8/8 [==============================] - 2s 310ms/step - loss: 0.0200 - val_loss: 0.0116
# Epoch 3/200
# 8/8 [==============================] - 2s 311ms/step - loss: 0.0065 - val_loss: 0.0036
# Epoch 4/200
# 8/8 [==============================] - 2s 305ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 5/200
# 8/8 [==============================] - 2s 304ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 6/200
# 8/8 [==============================] - 2s 306ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 7/200
# 8/8 [==============================] - 2s 308ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 8/200
# 8/8 [==============================] - 3s 313ms/step - loss: 9.0432e-04 - val_loss: 0.0012
# Epoch 9/200
# 8/8 [==============================] - 2s 309ms/step - loss: 8.3976e-04 - val_loss: 9.5029e-04
# Epoch 10/200
# 8/8 [==============================] - 2s 309ms/step - loss: 8.2230e-04 - val_loss: 9.3033e-04
# Epoch 11/200
# 8/8 [==============================] - 2s 309ms/step - loss: 7.8216e-04 - val_loss: 8.4099e-04
# Epoch 12/200
# 8/8 [==============================] - 3s 323ms/step - loss: 7.8489e-04 - val_loss: 8.1508e-04
# Epoch 13/200
# 8/8 [==============================] - 2s 308ms/step - loss: 8.2331e-04 - val_loss: 0.0011
# Epoch 14/200
# 8/8 [==============================] - 3s 316ms/step - loss: 7.9217e-04 - val_loss: 0.0015
# Epoch 15/200
# 8/8 [==============================] - 2s 310ms/step - loss: 8.3240e-04 - val_loss: 0.0013
# Epoch 16/200
# 8/8 [==============================] - 2s 308ms/step - loss: 8.1617e-04 - val_loss: 8.9095e-04
# Epoch 17/200
# 8/8 [==============================] - 2s 309ms/step - loss: 7.7647e-04 - val_loss: 9.3838e-04
# Epoch 18/200
# 8/8 [==============================] - 2s 309ms/step - loss: 7.5877e-04 - val_loss: 0.0012
# Epoch 19/200
# 8/8 [==============================] - 2s 309ms/step - loss: 7.3791e-04 - val_loss: 0.0013
# Epoch 20/200
# 8/8 [==============================] - 2s 310ms/step - loss: 8.0820e-04 - val_loss: 9.8145e-04
# Epoch 21/200
# 8/8 [==============================] - 3s 316ms/step - loss: 8.7319e-04 - val_loss: 9.4431e-04
# Epoch 22/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.8376e-04 - val_loss: 0.0011
# Epoch 23/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.9725e-04 - val_loss: 8.7984e-04
# Epoch 24/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.8585e-04 - val_loss: 0.0012
# Epoch 25/200
# 8/8 [==============================] - 3s 313ms/step - loss: 7.4583e-04 - val_loss: 8.5210e-04
# Epoch 26/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.2283e-04 - val_loss: 0.0011
# Epoch 27/200
# 8/8 [==============================] - 3s 314ms/step - loss: 6.9787e-04 - val_loss: 0.0011
# Epoch 28/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.4476e-04 - val_loss: 0.0010
# Epoch 29/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.7968e-04 - val_loss: 0.0011
# Epoch 30/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.3608e-04 - val_loss: 0.0011
# Epoch 31/200
# 8/8 [==============================] - 3s 317ms/step - loss: 7.6905e-04 - val_loss: 0.0011
# Epoch 32/200
# 8/8 [==============================] - 3s 309ms/step - loss: 9.0536e-04 - val_loss: 8.6337e-04
# Epoch 33/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.7032e-04 - val_loss: 0.0012
# Epoch 34/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.9723e-04 - val_loss: 8.8191e-04
# Epoch 35/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.5584e-04 - val_loss: 9.3707e-04
# Epoch 36/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.1820e-04 - val_loss: 0.0012
# Epoch 37/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.4473e-04 - val_loss: 0.0011
# Epoch 38/200
# 8/8 [==============================] - 3s 325ms/step - loss: 7.3680e-04 - val_loss: 9.3717e-04
# Epoch 39/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.7786e-04 - val_loss: 0.0012
# Epoch 40/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.7255e-04 - val_loss: 8.2043e-04
# Epoch 41/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.5321e-04 - val_loss: 0.0015
# Epoch 42/200
# 8/8 [==============================] - 3s 315ms/step - loss: 8.0842e-04 - val_loss: 8.6311e-04
# Epoch 43/200
# 8/8 [==============================] - 3s 316ms/step - loss: 8.4605e-04 - val_loss: 0.0014
# Epoch 44/200
# 8/8 [==============================] - 3s 312ms/step - loss: 8.7046e-04 - val_loss: 7.7175e-04
# Epoch 45/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.9780e-04 - val_loss: 0.0012
# Epoch 46/200
# 8/8 [==============================] - 2s 311ms/step - loss: 9.0674e-04 - val_loss: 0.0015
# Epoch 47/200
# 8/8 [==============================] - 3s 312ms/step - loss: 0.0011 - val_loss: 8.1696e-04
# Epoch 48/200
# 8/8 [==============================] - 2s 312ms/step - loss: 9.3575e-04 - val_loss: 0.0013
# Epoch 49/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.5039e-04 - val_loss: 9.8206e-04
# Epoch 50/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.3382e-04 - val_loss: 9.8084e-04
# Epoch 51/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.9661e-04 - val_loss: 8.7122e-04
# Epoch 52/200
# 8/8 [==============================] - 3s 314ms/step - loss: 7.5158e-04 - val_loss: 8.4436e-04
# Epoch 53/200
# 8/8 [==============================] - 3s 317ms/step - loss: 7.7407e-04 - val_loss: 9.9274e-04
# Epoch 54/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.1449e-04 - val_loss: 0.0010
# Epoch 55/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.3397e-04 - val_loss: 8.9315e-04
# Epoch 56/200
# 8/8 [==============================] - 3s 311ms/step - loss: 7.4057e-04 - val_loss: 0.0017
# Epoch 57/200
# 8/8 [==============================] - 2s 312ms/step - loss: 8.8513e-04 - val_loss: 8.0088e-04
# Epoch 58/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.4965e-04 - val_loss: 0.0011
# Epoch 59/200
# 8/8 [==============================] - 3s 314ms/step - loss: 7.3315e-04 - val_loss: 0.0011
# Epoch 60/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.9823e-04 - val_loss: 9.5290e-04
# Epoch 61/200
# 8/8 [==============================] - 3s 327ms/step - loss: 7.3924e-04 - val_loss: 8.8618e-04
# Epoch 62/200
# 8/8 [==============================] - 2s 310ms/step - loss: 8.3674e-04 - val_loss: 0.0010
# Epoch 63/200
# 8/8 [==============================] - 3s 313ms/step - loss: 7.6489e-04 - val_loss: 9.6160e-04
# Epoch 64/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.4253e-04 - val_loss: 9.3474e-04
# Epoch 65/200
# 8/8 [==============================] - 3s 312ms/step - loss: 7.5407e-04 - val_loss: 8.7573e-04
# Epoch 66/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.1235e-04 - val_loss: 0.0012
# Epoch 67/200
# 8/8 [==============================] - 2s 314ms/step - loss: 7.2577e-04 - val_loss: 8.7461e-04
# Epoch 68/200
# 8/8 [==============================] - 3s 313ms/step - loss: 8.5036e-04 - val_loss: 0.0019
# Epoch 69/200
# 8/8 [==============================] - 3s 318ms/step - loss: 8.7663e-04 - val_loss: 0.0012
# Epoch 70/200
# 8/8 [==============================] - 2s 312ms/step - loss: 8.0698e-04 - val_loss: 7.9875e-04
# Epoch 71/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.2258e-04 - val_loss: 8.1808e-04
# Epoch 72/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.2300e-04 - val_loss: 0.0010
# Epoch 73/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.1897e-04 - val_loss: 0.0013
# Epoch 74/200
# 8/8 [==============================] - 3s 327ms/step - loss: 7.7498e-04 - val_loss: 9.5473e-04
# Epoch 75/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.6984e-04 - val_loss: 0.0012
# Epoch 76/200
# 8/8 [==============================] - 2s 311ms/step - loss: 8.7621e-04 - val_loss: 0.0013
# Epoch 77/200
# 8/8 [==============================] - 3s 314ms/step - loss: 8.9528e-04 - val_loss: 8.6374e-04
# Epoch 78/200
# 8/8 [==============================] - 3s 312ms/step - loss: 7.9810e-04 - val_loss: 0.0012
# Epoch 79/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.5337e-04 - val_loss: 0.0010
# Epoch 80/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.2925e-04 - val_loss: 0.0013
# Epoch 81/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.8259e-04 - val_loss: 9.4428e-04
# Epoch 82/200
# 8/8 [==============================] - 2s 311ms/step - loss: 8.8263e-04 - val_loss: 0.0011
# Epoch 83/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.4254e-04 - val_loss: 9.5431e-04
# Epoch 84/200
# 8/8 [==============================] - 3s 314ms/step - loss: 7.3637e-04 - val_loss: 8.5458e-04
# Epoch 85/200
# 8/8 [==============================] - 3s 313ms/step - loss: 8.1597e-04 - val_loss: 7.7337e-04
# Epoch 86/200
# 8/8 [==============================] - 3s 312ms/step - loss: 8.6642e-04 - val_loss: 0.0013
# Epoch 87/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.4692e-04 - val_loss: 8.5868e-04
# Epoch 88/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.3699e-04 - val_loss: 9.4543e-04
# Epoch 89/200
# 8/8 [==============================] - 3s 317ms/step - loss: 8.3688e-04 - val_loss: 0.0015
# Epoch 90/200
# 8/8 [==============================] - 2s 311ms/step - loss: 9.8425e-04 - val_loss: 8.1859e-04
# Epoch 91/200
# 8/8 [==============================] - 3s 314ms/step - loss: 7.8870e-04 - val_loss: 0.0013
# Epoch 92/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.5454e-04 - val_loss: 8.1742e-04
# Epoch 93/200
# 8/8 [==============================] - 3s 315ms/step - loss: 8.1340e-04 - val_loss: 0.0012
# Epoch 94/200
# 8/8 [==============================] - 2s 314ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 95/200
# 8/8 [==============================] - 2s 311ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 96/200
# 8/8 [==============================] - 2s 311ms/step - loss: 8.0495e-04 - val_loss: 9.5204e-04
# Epoch 97/200
# 8/8 [==============================] - 3s 313ms/step - loss: 8.1941e-04 - val_loss: 9.8921e-04
# Epoch 98/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.7894e-04 - val_loss: 0.0011
# Epoch 99/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.7626e-04 - val_loss: 0.0011
# Epoch 100/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.5424e-04 - val_loss: 9.5994e-04
# Epoch 101/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.5782e-04 - val_loss: 8.1898e-04
# Epoch 102/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.4200e-04 - val_loss: 0.0013
# Epoch 103/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.7077e-04 - val_loss: 8.1409e-04
# Epoch 104/200
# 8/8 [==============================] - 3s 313ms/step - loss: 8.7864e-04 - val_loss: 7.9849e-04
# Epoch 105/200
# 8/8 [==============================] - 2s 311ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 106/200
# 8/8 [==============================] - 2s 310ms/step - loss: 0.0018 - val_loss: 9.0374e-04
# Epoch 107/200
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 108/200
# 8/8 [==============================] - 3s 317ms/step - loss: 0.0017 - val_loss: 7.7179e-04
# Epoch 109/200
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 110/200
# 8/8 [==============================] - 2s 310ms/step - loss: 0.0020 - val_loss: 8.5723e-04
# Epoch 111/200
# 8/8 [==============================] - 2s 313ms/step - loss: 0.0013 - val_loss: 8.1036e-04
# Epoch 112/200
# 8/8 [==============================] - 2s 310ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 113/200
# 8/8 [==============================] - 2s 312ms/step - loss: 9.8556e-04 - val_loss: 8.0794e-04
# Epoch 114/200
# 8/8 [==============================] - 2s 313ms/step - loss: 8.7784e-04 - val_loss: 9.8405e-04
# Epoch 115/200
# 8/8 [==============================] - 3s 314ms/step - loss: 8.3061e-04 - val_loss: 0.0015
# Epoch 116/200
# 8/8 [==============================] - 2s 311ms/step - loss: 8.1243e-04 - val_loss: 9.3649e-04
# Epoch 117/200
# 8/8 [==============================] - 3s 316ms/step - loss: 7.3539e-04 - val_loss: 9.9848e-04
# Epoch 118/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.0470e-04 - val_loss: 0.0010
# Epoch 119/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.4012e-04 - val_loss: 0.0011
# Epoch 120/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.5371e-04 - val_loss: 0.0010
# Epoch 121/200
# 8/8 [==============================] - 3s 316ms/step - loss: 7.3842e-04 - val_loss: 0.0011
# Epoch 122/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.4530e-04 - val_loss: 8.5327e-04
# Epoch 123/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.3977e-04 - val_loss: 9.2033e-04
# Epoch 124/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.1293e-04 - val_loss: 9.8943e-04
# Epoch 125/200
# 8/8 [==============================] - 3s 312ms/step - loss: 6.7497e-04 - val_loss: 0.0011
# Epoch 126/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.3640e-04 - val_loss: 9.5597e-04
# Epoch 127/200
# 8/8 [==============================] - 3s 329ms/step - loss: 8.0015e-04 - val_loss: 0.0012
# Epoch 128/200
# 8/8 [==============================] - 3s 316ms/step - loss: 8.1506e-04 - val_loss: 0.0011
# Epoch 129/200
# 8/8 [==============================] - 3s 317ms/step - loss: 7.5241e-04 - val_loss: 9.4619e-04
# Epoch 130/200
# 8/8 [==============================] - 3s 313ms/step - loss: 7.5161e-04 - val_loss: 9.0877e-04
# Epoch 131/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.0144e-04 - val_loss: 0.0012
# Epoch 132/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.6402e-04 - val_loss: 9.6219e-04
# Epoch 133/200
# 8/8 [==============================] - 3s 316ms/step - loss: 7.4619e-04 - val_loss: 0.0011
# Epoch 134/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.5079e-04 - val_loss: 8.2278e-04
# Epoch 135/200
# 8/8 [==============================] - 2s 313ms/step - loss: 8.0892e-04 - val_loss: 0.0011
# Epoch 136/200
# 8/8 [==============================] - 3s 316ms/step - loss: 6.8958e-04 - val_loss: 8.8513e-04
# Epoch 137/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.0003e-04 - val_loss: 9.2956e-04
# Epoch 138/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.5623e-04 - val_loss: 0.0011
# Epoch 139/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.5984e-04 - val_loss: 8.4152e-04
# Epoch 140/200
# 8/8 [==============================] - 3s 320ms/step - loss: 7.8470e-04 - val_loss: 0.0012
# Epoch 141/200
# 8/8 [==============================] - 3s 316ms/step - loss: 8.6317e-04 - val_loss: 8.5880e-04
# Epoch 142/200
# 8/8 [==============================] - 3s 313ms/step - loss: 7.9822e-04 - val_loss: 9.3610e-04
# Epoch 143/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.6014e-04 - val_loss: 9.4725e-04
# Epoch 144/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.2030e-04 - val_loss: 0.0011
# Epoch 145/200
# 8/8 [==============================] - 3s 317ms/step - loss: 7.7280e-04 - val_loss: 9.2049e-04
# Epoch 146/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.1645e-04 - val_loss: 0.0011
# Epoch 147/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.2219e-04 - val_loss: 0.0013
# Epoch 148/200
# 8/8 [==============================] - 3s 315ms/step - loss: 8.1847e-04 - val_loss: 8.3834e-04
# Epoch 149/200
# 8/8 [==============================] - 3s 317ms/step - loss: 8.1405e-04 - val_loss: 0.0012
# Epoch 150/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.7005e-04 - val_loss: 7.8989e-04
# Epoch 151/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.3711e-04 - val_loss: 0.0013
# Epoch 152/200
# 8/8 [==============================] - 3s 313ms/step - loss: 8.1638e-04 - val_loss: 8.1790e-04
# Epoch 153/200
# 8/8 [==============================] - 3s 312ms/step - loss: 8.9047e-04 - val_loss: 0.0021
# Epoch 154/200
# 8/8 [==============================] - 3s 312ms/step - loss: 8.9714e-04 - val_loss: 9.6842e-04
# Epoch 155/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.3966e-04 - val_loss: 8.7490e-04
# Epoch 156/200
# 8/8 [==============================] - 3s 312ms/step - loss: 7.2842e-04 - val_loss: 0.0011
# Epoch 157/200
# 8/8 [==============================] - 3s 314ms/step - loss: 7.2015e-04 - val_loss: 0.0011
# Epoch 158/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.6537e-04 - val_loss: 8.0197e-04
# Epoch 159/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.7835e-04 - val_loss: 0.0015
# Epoch 160/200
# 8/8 [==============================] - 3s 314ms/step - loss: 8.6285e-04 - val_loss: 9.6192e-04
# Epoch 161/200
# 8/8 [==============================] - 3s 312ms/step - loss: 7.6902e-04 - val_loss: 0.0012
# Epoch 162/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.4590e-04 - val_loss: 9.7905e-04
# Epoch 163/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.1752e-04 - val_loss: 9.9197e-04
# Epoch 164/200
# 8/8 [==============================] - 3s 315ms/step - loss: 8.1048e-04 - val_loss: 9.8934e-04
# Epoch 165/200
# 8/8 [==============================] - 2s 313ms/step - loss: 8.5931e-04 - val_loss: 8.4429e-04
# Epoch 166/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.9384e-04 - val_loss: 0.0015
# Epoch 167/200
# 8/8 [==============================] - 2s 314ms/step - loss: 8.3709e-04 - val_loss: 9.2297e-04
# Epoch 168/200
# 8/8 [==============================] - 3s 322ms/step - loss: 7.4376e-04 - val_loss: 8.6310e-04
# Epoch 169/200
# 8/8 [==============================] - 2s 311ms/step - loss: 8.5991e-04 - val_loss: 9.8629e-04
# Epoch 170/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.7358e-04 - val_loss: 0.0012
# Epoch 171/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.6682e-04 - val_loss: 9.6257e-04
# Epoch 172/200
# 8/8 [==============================] - 3s 316ms/step - loss: 7.0095e-04 - val_loss: 0.0012
# Epoch 173/200
# 8/8 [==============================] - 3s 314ms/step - loss: 7.3420e-04 - val_loss: 9.3413e-04
# Epoch 174/200
# 8/8 [==============================] - 3s 317ms/step - loss: 7.6537e-04 - val_loss: 0.0011
# Epoch 175/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.4078e-04 - val_loss: 9.0956e-04
# Epoch 176/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.4207e-04 - val_loss: 0.0014
# Epoch 177/200
# 8/8 [==============================] - 3s 315ms/step - loss: 7.7131e-04 - val_loss: 8.2610e-04
# Epoch 178/200
# 8/8 [==============================] - 2s 313ms/step - loss: 7.3080e-04 - val_loss: 0.0014
# Epoch 179/200
# 8/8 [==============================] - 3s 320ms/step - loss: 7.3424e-04 - val_loss: 8.2120e-04
# Epoch 180/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.2942e-04 - val_loss: 0.0011
# Epoch 181/200
# 8/8 [==============================] - 3s 313ms/step - loss: 7.8513e-04 - val_loss: 8.6627e-04
# Epoch 182/200
# 8/8 [==============================] - 3s 316ms/step - loss: 7.3255e-04 - val_loss: 9.7969e-04
# Epoch 183/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.1880e-04 - val_loss: 0.0012
# Epoch 184/200
# 8/8 [==============================] - 3s 318ms/step - loss: 7.7741e-04 - val_loss: 0.0012
# Epoch 185/200
# 8/8 [==============================] - 2s 311ms/step - loss: 9.1680e-04 - val_loss: 0.0011
# Epoch 186/200
# 8/8 [==============================] - 3s 312ms/step - loss: 7.8745e-04 - val_loss: 0.0012
# Epoch 187/200
# 8/8 [==============================] - 3s 320ms/step - loss: 7.7891e-04 - val_loss: 8.6732e-04
# Epoch 188/200
# 8/8 [==============================] - 2s 312ms/step - loss: 8.3830e-04 - val_loss: 0.0016
# Epoch 189/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.8184e-04 - val_loss: 0.0012
# Epoch 190/200
# 8/8 [==============================] - 2s 312ms/step - loss: 7.7792e-04 - val_loss: 8.0697e-04
# Epoch 191/200
# 8/8 [==============================] - 3s 314ms/step - loss: 7.6172e-04 - val_loss: 0.0012
# Epoch 192/200
# 8/8 [==============================] - 2s 310ms/step - loss: 7.6273e-04 - val_loss: 9.7094e-04
# Epoch 193/200
# 8/8 [==============================] - 3s 313ms/step - loss: 8.8910e-04 - val_loss: 0.0017
# Epoch 194/200
# 8/8 [==============================] - 3s 318ms/step - loss: 8.5756e-04 - val_loss: 9.2183e-04
# Epoch 195/200
# 8/8 [==============================] - 2s 311ms/step - loss: 9.2577e-04 - val_loss: 0.0012
# Epoch 196/200
# 8/8 [==============================] - 3s 315ms/step - loss: 9.3698e-04 - val_loss: 9.6196e-04
# Epoch 197/200
# 8/8 [==============================] - 2s 311ms/step - loss: 8.7256e-04 - val_loss: 0.0012
# Epoch 198/200
# 8/8 [==============================] - 2s 311ms/step - loss: 9.2726e-04 - val_loss: 0.0012
# Epoch 199/200
# 8/8 [==============================] - 2s 311ms/step - loss: 7.3645e-04 - val_loss: 8.9869e-04
# Epoch 200/200
# 8/8 [==============================] - 3s 327ms/step - loss: 7.1183e-04 - val_loss: 9.7392e-04

# %% [markdown]
# ## 6. 評估模型

# %%
l1, = plt.plot(history.history['loss'])
l2, = plt.plot(history.history['val_loss'])
plt.legend(handles=[l1,l2],labels=['loss','val_loss'],loc='best')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.show()

# %%
test_company = test_df[test_df["company"] == company_id]
test_company.head()
# Out:
#      company      date  price
# 116     2317  2021/2/1  113.0
# 115     2317  2021/2/2  116.5
# 114     2317  2021/2/3  116.5
# 113     2317  2021/2/4  114.0
# 112     2317  2021/2/5  113.5

# %% [markdown]
# ## 7. 做預測 (20分)

# %%
# 預測 Test data
# 現在我們取出了選定公司最後seq_len天
# 我們模型透過讀取seq_len天後預測出seq_len+1天的價格

# 將日期保存在datas中 (list)
# 將真實價格保存在real_prices中 (list)
# 將預測價格保存在pred_prices中 (list) *注: 請填入經過正規化後的價格

# input是一個經過**正規化**的真實價格list，請試著遍歷test_company來填滿上述三個list
# 可以參考TextGeneration的generateWords function，概念一樣，但是這次input請全部都填入"真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"

init_price = company.iloc[-seq_len:,:]["price"].values
dates = []
real_prices = []
pred_prices = []
input = scalar.transform(init_price)

for index,row in test_company.iterrows():
  # 我已經幫你把real_price和date放入list
  real_price = row["price"]
  real_prices.append(real_price)
  date = row["date"]
  dates.append(date)

  # 參考步驟 (在for迴圈中) :
  # 1. 把input轉**維度**成一個新變數next_input丟入model
  next_input = tf.expand_dims(input,axis=-1)
  next_input = tf.expand_dims(next_input,axis=0)
  # 2. 獲得的pred取出seq中最後一個時間點的output數值 (提示: [0,-1,0])
  predicts = model(next_input)
  predicts = predicts[0,-1,0]
  # 3. 把pred丟入pred_prices中
  pred_prices.append(float(predicts))
  # 4. 把real_price經過transform_one轉換成小數點並加在input後面
  real_price = scalar.transform_one(real_price)
  input.append(real_price)
  # 5. 保持input長度為seq_len長 (也就是把最前面的數字踢掉)
  input = input[1:]
  ##########
  # todo #
  ##########

# %%
print(f"dates : {dates[:10]}")
print(f"real_prices : {real_prices[:10]}")
print(f"pred_prices : {pred_prices[:10]}")
# Out:
# dates : ['2021/2/1', '2021/2/2', '2021/2/3', '2021/2/4', '2021/2/5', '2021/2/17', '2021/2/18', '2021/2/19', '2021/2/22', '2021/2/23']
# real_prices : [113.0, 116.5, 116.5, 114.0, 113.5, 114.0, 113.0, 110.0, 111.0, 111.5]
# pred_prices : [0.8084665536880493, 0.824752151966095, 0.8853307962417603, 0.8902018666267395, 0.8484851121902466, 0.8345065116882324, 0.8400695323944092, 0.826102077960968, 0.7751286625862122, 0.7894737720489502]

# %% [markdown]
# * 預期結果:
#
# ![](https://i.imgur.com/iXdMWD6.png)

# %%
plt.figure(figsize=(16, 8))
l1, = plt.plot(dates,real_prices)
l2, = plt.plot(dates,scalar.recover(pred_prices))
plt.xticks(list(include_last_iter(0,len(dates),3)),rotation=30)
plt.legend(handles=[l1,l2],labels=['Real','Pred'],loc='best')
plt.title(companys[str(company_id)])
plt.xlabel("Date")
plt.ylabel("price")
plt.show()

# %% [markdown]
# * 預期成果
#
# 照理來說不會100%猜中，猜中幾乎100%可能是不小心偷看答案了。
#
# 不過要是你的模型正確的話，應該會看到如下pred price在true price附近而不是躺在地上。
#
# ![](https://i.imgur.com/tFoKEyK.png)
